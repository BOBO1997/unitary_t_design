# %% [markdown]
# # Local Random Clifford (simulator)

# %%
import qiskit
from qiskit import IBMQ, Aer
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute
import qiskit.quantum_info as qi
from qiskit.visualization import plot_histogram

# %%
# IBMQ.load_account()
# provider = IBMQ.get_provider(hub='ibm-q-utokyo', group='internal', project='hirashi-jst')

# %%
import sys
sys.path.append("../")

# %%
import random
import numpy as np
import importlib
import pickle
import time
from pprint import pprint
import matplotlib.pyplot as plt

# %%
from test_unitaries import *

# %%
np.random.seed(seed=42)
seed = 42 # random seed
num_data = 200 # original: 10000
Nq = 4 # number of qubit
Ns = 1000

# %%
results = []

# %%
def decide_lrc_depth(t, eps, n):
    D = np.ceil(t ** 9 * (n * t + np.log2(1 / eps)))
    return int(D)

# %%
def decide_rdc_depth(t, eps, n):
    D = np.ceil(2 * t - np.log2(eps) / n)
    return int(D)

# %%
for i in range(1, num_data + 1):
    t1 = time.time()
    qc = QuantumCircuit(Nq, Nq)
    D = 2
    qc.append(LRC(Nq, D, to_gate=True, seeds = [4 * (i - 1) + j for j in range(4)]), range(Nq))
    qc.measure(range(Nq), range(Nq)[::-1])
    results.append(execute(qc, shots = Ns, backend = Aer.get_backend("qasm_simulator"), seed_transpiler=seed, seed_simulator=seed).result())
    t2 = time.time()
    if i % 100 == 0:
        print("added", i, "th data (", t2 - t1, "s)")
        with open("test_data_lrc_depth2_simulator.pkl", "wb") as f:
            pickle.dump(results, f)
# Out:
# added 100 th data ( 0.008295297622680664 s)
# added 200 th data ( 0.008600950241088867 s)

# %%
def results_to_counts(results):
    counts = []
    for result in results:
        counts.append(result.get_counts())
    return counts

# %%
counts = results_to_counts(results)

# %%
plot_histogram(counts[0])

# %%
plot_histogram(counts[1])

# %%
plot_histogram(counts[2])

# %%
plot_histogram(counts[3])

# %%
plot_histogram(counts[4])

# %%
from qiskit.compiler import transpile
qc = QuantumCircuit(Nq, Nq)
D = 2
qc.append(LRC(Nq, D, to_gate=True, seeds = [0,1,2,3]), range(Nq))
tqc = transpile(qc, backend = Aer.get_backend("qasm_simulator"), basis_gates=["u1", "u2", "u3", "cx"], approximation_degree=0)
tqc.count_ops(), tqc.depth()
# Out:
# (OrderedDict([('u3', 22), ('cx', 9)]), 13)

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-utokyo', group='internal', project='hirashi-jst')

# %%
ibmq_montreal = provider.get_backend("ibmq_montreal")

# %%
from qiskit.compiler import transpile
qc = QuantumCircuit(Nq, Nq)
D = 2
qc.append(LRC(Nq, D, to_gate=True, seeds = [0,1,2,3]), range(Nq))
tqc = transpile(qc, backend = ibmq_montreal, approximation_degree=1)
tqc.count_ops(), tqc.depth()
# Out:
# (OrderedDict([('rz', 63), ('sx', 44), ('cx', 9)]), 41)

# %%
from qiskit.compiler import transpile
ops = []
depth = []
for D in range(2,9):
    qc = QuantumCircuit(Nq, Nq)
    qc.append(LRC(Nq, D, to_gate=True, seeds = [0,1,2,3]), range(Nq))
    tqc = transpile(qc, backend = ibmq_montreal, approximation_degree=0)
    ops.append(tqc.count_ops())
    depth.append(tqc.depth())

# %%
ops
# Out:
# [OrderedDict([('rz', 63), ('sx', 44), ('cx', 9)]),
#  OrderedDict([('rz', 97), ('sx', 68), ('cx', 15)]),
#  OrderedDict([('rz', 114), ('sx', 80), ('cx', 18)]),
#  OrderedDict([('rz', 148), ('sx', 104), ('cx', 24)]),
#  OrderedDict([('rz', 165), ('sx', 116), ('cx', 27)]),
#  OrderedDict([('rz', 199), ('sx', 140), ('cx', 33)]),
#  OrderedDict([('rz', 216), ('sx', 152), ('cx', 36)])]

# %%
ops_rz = [ops[i]["rz"] for i in range(len(ops))]
ops_sx = [ops[i]["sx"] for i in range(len(ops))]
ops_cx = [ops[i]["cx"] for i in range(len(ops))]

# %%
plt.plot(depth)
plt.plot(ops_rz)
plt.plot(ops_sx)
plt.plot(ops_cx)
plt.legend(["depth", "rx", "sx", "cx"])
plt.show()

# %%
from qiskit.compiler import transpile
ops = []
depth = []
for D in range(2,9):
    qc = QuantumCircuit(Nq, Nq)
    qc.append(RDC(Nq, D, to_gate=True, seed = 0), range(Nq))
    tqc = transpile(qc, backend = ibmq_montreal, approximation_degree=0)
    ops.append(tqc.count_ops())
    depth.append(tqc.depth())

# %%
ops_rz = [ops[i]["rz"] for i in range(len(ops))]
ops_sx = [ops[i]["sx"] for i in range(len(ops))]
ops_cx = [ops[i]["cx"] for i in range(len(ops))]

# %%
plt.plot(depth)
plt.plot(ops_rz)
plt.plot(ops_sx)
plt.plot(ops_cx)
plt.legend(["depth", "rx", "sx", "cx"])
plt.show()
